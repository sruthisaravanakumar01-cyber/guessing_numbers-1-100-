# %% [markdown]
# <a href="https://colab.research.google.com/github/sruthisaravanakumar01-cyber/guessing_numbers-1-100-/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 3: Number Guessing Game
# Name: Sruthi
# ============================================

import random

def number_guessing_game():
    secret_number = random.randint(1, 100)
    attempts = 0

    print("=" * 40)
    print("   Welcome to the Number Guessing Game!")
    print("=" * 40)
    print("I'm thinking of a number between 1 and 100.")
    print("Can you guess it?\n")

    while True:
        try:
            guess = int(input("Enter your guess: "))

            if guess < 1 or guess > 100:
                print("Please enter a number between 1 and 100.\n")
                continue

            attempts += 1

            if guess < secret_number:
                print(f"{guess} is too LOW! Try higher.\n")
            elif guess > secret_number:
                print(f"{guess} is too HIGH! Try lower.\n")
            else:
                print(f"\nYou got it! The number was {secret_number}.")
                print(f"You solved it in {attempts} attempt(s)!")
                break

        except ValueError:
            print("Invalid input! Please enter a valid number.\n")

    play_again = input("\nPlay again? (yes/no): ").lower()
    if play_again == "yes":
        number_guessing_game()
    else:
        print("Thanks for playing!")

number_guessing_game()
# Out:
# ...
#    Welcome to the Number Guessing Game!
# ...
# I'm thinking of a number between 1 and 100.
# Can you guess it?
#
# Enter your guess: 45
# 45 is too LOW! Try higher.
#
# Enter your guess: 89
# 89 is too HIGH! Try lower.
#
# Enter your guess: 15
# 15 is too LOW! Try higher.
#
# Enter your guess: 50
# 50 is too HIGH! Try lower.
#
# Enter your guess: 40
# 40 is too LOW! Try higher.
#
# Enter your guess: 49
# 49 is too HIGH! Try lower.
#
# Enter your guess: 45
# 45 is too LOW! Try higher.
#
# Enter your guess: 46
# 46 is too LOW! Try higher.
#
# Enter your guess: 47
#
# You got it! The number was 47.
# You solved it in 9 attempt(s)!
